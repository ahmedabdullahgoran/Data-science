# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ahmed Abdullah**
#
# I am currently working as IT operations officer in united nation, my desier is to become a professnial data scientest and analysis.

# %% [markdown]
# *I am interested in data science because I love to explore data and provide insight for the decission makers that enables them to make a data-driven decissios, I am also a corious person who loves to descover a stories from data*

# %% [markdown]
# ### the below code is for assigning two integer numbers to two variables and print the sum of these integer numbers.

# %%
a = 10
b = 5
print("the total of a and b =",a+b)
# Out:
# the total of a and b = 15

# %% [markdown]
# Bulleted list:
# - Item 1
# - Item 2
# - Item 3
#
# numbered list:
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# __[Go to google](http://google.com)__
